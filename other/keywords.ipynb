# %%
def readfile(file):
    with open(file, "r",encoding='utf-8',errors='ignore') as f:  # 打开文件
        data = f.read()  # 读取文件
        return data

# %%
sfile = 'C:\\Users\\root\\Desktop\\Trump1_xaa.txt'
str =  readfile(sfile)
print(str)
# Out:
# text
# Thank you Steve. The greatest Witch Hunt in U.S. history! https://t.co/I3bSNVp6gC
# Our fantastic First Lady! https://t.co/6iswto4WDI
# HAPPY NEW YEAR!
# Best equipment &amp, finest military in the World. On site quickly! https://t.co/cDUtqFLLYB
# Too bad, Corey would have won! He (and I) loves New Hampshire. https://t.co/d2e1NUkDwR
# Can’t believe @ATT keeps the management after yet another @CNN ratings dive. Nobody watching, NO CREDIBILITY! Maybe they should make changes at AT&amp,T? https://t.co/jdCLuNWEEQ
# Great job! https://t.co/qNUVbEdMz6
# They don’t know how to do that! https://t.co/1Vg1O9yJHj
# Sohrab Ahmari, New York Post “The Trump Campaign raised $10 million in the two days following the impeachment (Scam) vote. It seems the Democrats have shot themselves in the foot in one more way. They set up a process they know is not going to lead to the Presidents removal, &amp,...
# ...

# %%
from summa import summarizer
print(summarizer.summarize(str, ratio=0.02))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a7c1e6de971d> in <module>
#       1 from summa import summarizer
# ----> 2 print(summarizer.summarize(str, ratio=0.02))
#
# ~\anaconda3\lib\site-packages\summa\summarizer.py in summarize(text, ratio, words, language, split, scores, additional_stopwords)
#     119     # Creates the graph and calculates the similarity coefficient for every pair of nodes.
#     120     graph = _build_graph([sentence.token for sentence in sentences])
# --> 121     _set_graph_edge_weights(graph)
#     122
#     123     # Remove all nodes with all edges weights equal to zero.
#
# ~\anaconda3\lib\site-packages\summa\summarizer.py in _set_graph_edge_weights(graph)
#      15                 similarity = _get_similarity(sentence_1, sentence_2)
#      16                 if similarity != 0:
# ...

# %%
from summa import keywords
print(keywords.keywords(str, words=30))
# Out:
# https
# amp
# thank
# thanks
# thanking
# great
# greatly
# greatness
# greats
# big
# democrats
# democrat
# democratic
# people
# news
# congratulations
# congratulate
# congressman
# job
# jobs
# new
# fake
# trump
# foxnews
# good
# goods
# like
# likes
# liked
# m
# senator
# senate
# senators
# americans
# american
# presidents
# president
# presidency
# presides
# today
# todays
# joe
# states
# state
# stated
# j
# year
# years
# yearly
# john
# h
# biden
# bidens
# make
# making
# makes

# %%
from nltk import word_tokenize     #以空格形式实现分词
words = word_tokenize(str)
print(words)

# %%
from nltk import sent_tokenize #以符号形式实现分句
sentence = sent_tokenize(str )
print(sentence)
# Out:
# ['\n### picture data found, picture dimensions are 215 by 40, depth 1\npict014.png\n\n\n\nResidents wearing masks to protect themselves from the coronavirus watch a...\n\nSTF, Ng Han Guan \nThe Associated Press\n90 [W\n2020 ^t 11 g\x08 6 e\nAP Photostream\nAPPIC\n\x1ae!', 'Copyright 2020.', 'The Associated Press.', 'All Rights Reserved.', 'Residents wearing masks to protect themselves from the coronavirus watch a promotion event involving foreign models in Beijing on Friday, Nov. 6, 2020.', 'China has temporarily banned the entry of foreigners from at least eight countries as COVID-19 cases rise in Europe and elsewhere, as part of its strict measures that have largely ended domestic transmission of the virus.', '(AP Photo/Ng Han Guan)\n\nTransmission Reference: XHG107; Slug: China Virus Outbreak']

# %%
from nltk import word_tokenize
cutwords1 = word_tokenize(str)   #分词
print('【NLTK分词结果：】')
print(cutwords1)

interpunctuations = [',', '.', ':', ';', '?', '(', ')', '[', ']', '&', '!', '*', '@', '#', '$', '%']   #定义标点符号列表
cutwords2 = [word for word in cutwords1 if word not in interpunctuations]   #去除标点符号
print('\n【NLTK分词后去除符号结果：】')
print(cutwords2)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
