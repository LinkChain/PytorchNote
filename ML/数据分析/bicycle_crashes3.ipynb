# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline
mpl.rcParams['font.sans-serif'] = ['simhei']
mpl.rcParams['font.serif'] = ['simhei']
plt.rc("font",family="SimHei",size="14") 
sns.set_style("darkgrid")

xls = pd.ExcelFile('C:/Users/Administrator/Desktop/data/bicycle crash data.xlsx')
df = pd.read_excel(xls,'Sheet')
df.head()
# Out:
#                        Geo Point  \
# 0  35.9100670923, -79.0745027481
# 1  36.0151171157, -79.0306027406
# 2  35.9889631116, -78.9887827261
# 3  35.9227900944, -79.0888327525
# 4  36.0100771166, -78.9900027276
#
#                                            Geo Shape Ambulance  \
# 0  {u'type': u'Point', u'coordinates': [-79.07450...       Yes
# 1  {u'type': u'Point', u'coordinates': [-79.03060...        No
# 2  {u'type': u'Point', u'coordinates': [-78.98878...       Yes
# 3  {u'type': u'Point', u'coordinates': [-79.08883...       Yes
# 4  {u'type': u'Point', u'coordinates': [-78.99000...       Yes
#
#   Biker Age Group Biker Age Bike Direction        Biker Injury Bike Position  \
# 0             70+       70+   With Traffic           K: Killed   Travel Lane
# 1           20-24        24   With Traffic  C: Possible Injury   Travel Lane
# 2           25-29        26   With Traffic   B: Evident Injury   Travel Lane
# 3           30-39        33   With Traffic   B: Evident Injury   Travel Lane
# 4           40-49        41   With Traffic   B: Evident Injury   Travel Lane
#
#   Biker Race Biker Sex  ... Road Condition    Road Configuration Road Defects  \
# 0      White      Male  ...            Dry  Two-Way, Not Divided         None
# 1      White      Male  ...            Dry  Two-Way, Not Divided         None
# 2      Black      Male  ...            Dry  Two-Way, Not Divided         None
# 3      White    Female  ...            Dry  Two-Way, Not Divided         None
# 4      White    Female  ...            Dry  Two-Way, Not Divided         None
#
#             Road Feature    Road Surface Rural/Urban   Speed Limit  \
# 0     No Special Feature  Smooth Asphalt       Urban  20 - 25  MPH
# 1      Driveway, Private  Coarse Asphalt       Rural  40 - 45  MPH
# 2     No Special Feature  Smooth Asphalt       Urban  40 - 45  MPH
# 3         T-Intersection  Smooth Asphalt       Urban  30 - 35  MPH
# 4  Four-Way Intersection  Smooth Asphalt       Rural  40 - 45  MPH
#
#                        Traffic Control Weather  Workzone
# 0                   No Control Present   Clear        No
# 1  Double Yellow Line, No Passing Zone   Clear        No
# 2  Double Yellow Line, No Passing Zone   Clear        No
# 3                              Missing   Clear        No
# 4                            Stop Sign   Clear        No
#
# [5 rows x 48 columns]

# %%
df.describe()
# Out:
#               Year  Number of Units
# count   165.000000       165.000000
# mean   2010.006061         2.018182
# std       1.933331         0.134015
# min    2007.000000         2.000000
# 25%    2008.000000         2.000000
# 50%    2010.000000         2.000000
# 75%    2012.000000         2.000000
# max    2013.000000         3.000000
